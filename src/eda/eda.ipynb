# %%
# !pip install wandb==0.16.0
# !pip install ydata-profiling==4.12.1
# !pip install pandas==2.1.3
# Out:
# Requirement already satisfied: wandb==0.16.0 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (0.16.0)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (8.1.8)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (3.1.44)
# Requirement already satisfied: requests<3,>=2.0.0 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (2.32.3)
# Requirement already satisfied: psutil>=5.0.0 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (7.0.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (2.27.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (0.4.0)
# Requirement already satisfied: PyYAML in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (6.0.2)
# Requirement already satisfied: setproctitle in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (1.3.5)
# Requirement already satisfied: setuptools in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (79.0.1)
# Requirement already satisfied: appdirs>=1.4.3 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (4.25.7)
# Requirement already satisfied: six>=1.4.0 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb==0.16.0) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb==0.16.0) (4.0.12)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (2025.1.31)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb==0.16.0) (5.0.2)
# Collecting ydata-profiling==4.12.1
#   Using cached ydata_profiling-4.12.1-py2.py3-none-any.whl.metadata (20 kB)
# Collecting scipy<1.14,>=1.4.1 (from ydata-profiling==4.12.1)
#   Downloading scipy-1.13.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from ydata-profiling==4.12.1) (2.1.3)
# Requirement already satisfied: matplotlib<3.10,>=3.5 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from ydata-profiling==4.12.1) (3.8.2)
# Collecting pydantic>=2 (from ydata-profiling==4.12.1)
#   Downloading pydantic-2.11.4-py3-none-any.whl.metadata (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.6/66.6 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from ydata-profiling==4.12.1) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from ydata-profiling==4.12.1) (3.1.6)
# Collecting visions<0.7.7,>=0.7.5 (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling==4.12.1)
#   Using cached visions-0.7.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from ydata-profiling==4.12.1) (1.26.4)
# Collecting htmlmin==0.1.12 (from ydata-profiling==4.12.1)
#   Using cached htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling==4.12.1)
#   Downloading phik-0.12.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.24.0 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from ydata-profiling==4.12.1) (2.32.3)
# Collecting tqdm<5,>=4.48.2 (from ydata-profiling==4.12.1)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting seaborn<0.14,>=0.10.1 (from ydata-profiling==4.12.1)
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting multimethod<2,>=1.4 (from ydata-profiling==4.12.1)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Collecting statsmodels<1,>=0.13.2 (from ydata-profiling==4.12.1)
#   Downloading statsmodels-0.14.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Collecting typeguard<5,>=3 (from ydata-profiling==4.12.1)
#   Downloading typeguard-4.4.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting imagehash==4.3.1 (from ydata-profiling==4.12.1)
#   Using cached ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting wordcloud>=1.9.3 (from ydata-profiling==4.12.1)
#   Downloading wordcloud-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting dacite>=1.8 (from ydata-profiling==4.12.1)
#   Using cached dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Collecting numba<1,>=0.56.0 (from ydata-profiling==4.12.1)
#   Downloading numba-0.61.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Collecting PyWavelets (from imagehash==4.3.1->ydata-profiling==4.12.1)
#   Downloading pywavelets-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: pillow in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from imagehash==4.3.1->ydata-profiling==4.12.1) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling==4.12.1) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (2.9.0.post0)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba<1,>=0.56.0->ydata-profiling==4.12.1)
#   Downloading llvmlite-0.44.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: pytz>=2020.1 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling==4.12.1) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling==4.12.1) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from phik<0.13,>=0.11.1->ydata-profiling==4.12.1) (1.4.2)
# Collecting annotated-types>=0.6.0 (from pydantic>=2->ydata-profiling==4.12.1)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic>=2->ydata-profiling==4.12.1)
#   Downloading pydantic_core-2.33.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pydantic>=2->ydata-profiling==4.12.1) (4.13.2)
# Collecting typing-inspection>=0.4.0 (from pydantic>=2->ydata-profiling==4.12.1)
#   Downloading typing_inspection-0.4.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (2025.1.31)
# Collecting patsy>=0.5.6 (from statsmodels<1,>=0.13.2->ydata-profiling==4.12.1)
#   Using cached patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: attrs>=19.3.0 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling==4.12.1) (25.3.0)
# Collecting networkx>=2.4 (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling==4.12.1)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# WARNING: visions 0.7.6 does not provide the extra 'type-image-path'
# Requirement already satisfied: six>=1.5 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (1.17.0)
# Using cached ydata_profiling-4.12.1-py2.py3-none-any.whl (390 kB)
# Using cached ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# Using cached dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading numba-0.61.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 12.7 MB/s eta 0:00:000:00:010:00:01:01
# Downloading phik-0.12.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (686 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 15.4 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading pydantic-2.11.4-py3-none-any.whl (443 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.9/443.9 kB 14.7 MB/s eta 0:00:00
# Downloading pydantic_core-2.33.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 16.3 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading scipy-1.13.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 17.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading statsmodels-0.14.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 20.9 MB/s eta 0:00:00m eta 0:00:0136m0:00:01
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typeguard-4.4.2-py3-none-any.whl (35 kB)
# Using cached visions-0.7.6-py3-none-any.whl (104 kB)
# Downloading wordcloud-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.1/511.1 kB 15.7 MB/s eta 0:00:00
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading llvmlite-0.44.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 14.7 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 21.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Using cached patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Downloading typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Downloading pywavelets-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 18.3 MB/s eta 0:00:00 MB/s eta 0:00:01
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27161 sha256=9c99a365e015150d81a8acce56d05ef7a3c2582124c787e6c89edb0256e899c3
#   Stored in directory: /home/adamichaelf/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# Installing collected packages: htmlmin, typing-inspection, typeguard, tqdm, scipy, PyWavelets, pydantic-core, patsy, networkx, multimethod, llvmlite, dacite, annotated-types, pydantic, numba, imagehash, wordcloud, visions, statsmodels, seaborn, phik, ydata-profiling
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.2
#     Uninstalling scipy-1.15.2:
#       Successfully uninstalled scipy-1.15.2
# Successfully installed PyWavelets-1.8.0 annotated-types-0.7.0 dacite-1.9.2 htmlmin-0.1.12 imagehash-4.3.1 llvmlite-0.44.0 multimethod-1.12 networkx-3.4.2 numba-0.61.2 patsy-1.0.1 phik-0.12.4 pydantic-2.11.4 pydantic-core-2.33.2 scipy-1.13.1 seaborn-0.13.2 statsmodels-0.14.4 tqdm-4.67.1 typeguard-4.4.2 typing-inspection-0.4.0 visions-0.7.6 wordcloud-1.9.4 ydata-profiling-4.12.1
# Requirement already satisfied: pandas==2.1.3 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (2.1.3)
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas==2.1.3) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas==2.1.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas==2.1.3) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas==2.1.3) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/adamichaelf/miniconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas==2.1.3) (1.17.0)

# %% [markdown]
# 1. Fetch the artifact we just created (sample.csv) from W&B and read it with pandas:

# %%
import wandb
import pandas as pd
# Note that we use save_code=True in the call to wandb.init so the notebook is uploaded and versioned by W&B
run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
local_path = wandb.use_artifact("sample.csv:latest").file()
df = pd.read_csv(local_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import wandb
#       2 import pandas as pd
#       3 # Note that we use save_code=True in the call to wandb.init so the notebook is uploaded and versioned by W&B
#
# ModuleNotFoundError: No module named 'wandb'

# %% [markdown]
# 2. Explore the data in df

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# 3. What do you notice in the data? Look around and see what you can find.
#
# > For example, there are missing values in a few columns and the column `last_review` is a date but it is in string format. Look also at the `price` column, and note the outliers. There are some zeros and some very high prices. After talking to your stakeholders, you decide to consider from a minimum of `$10` to a maximum of `$350` per night.

# %% [markdown]
# 4. Fix some of the little problems we have found in the data with the following code:

# %%
# Drop outliers
min_price = 10
max_price = 350
idx = df['price'].between(min_price, max_price)
df = df[idx].copy()
# Convert last_review to datetime
df['last_review'] = pd.to_datetime(df['last_review'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       2 min_price = 10
#       3 max_price = 350
# ----> 4 idx = df['price'].between(min_price, max_price)
#       5 df = df[idx].copy()
#       6 # Convert last_review to datetime
#
# NameError: name 'df' is not defined

# %% [markdown]
# Note how we did not impute missing values. We will do that in the inference pipeline, so we will be able to handle missing values also in production.

# %% [markdown]
# 5. Check with df.info() that all obvious problems have been solved

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %% [markdown]
# 6. Terminate the run by running `run.finish()`

# %%
run.finish()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 run.finish()
#
# NameError: name 'run' is not defined

# %% [markdown]
# 7. Save the notebook.
